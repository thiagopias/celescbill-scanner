# %%
import tabula
import PyPDF2
import pandas as pd
import os
from datetime import datetime

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
#pdfFile = open('celesc.pdf','rb')
#pdf = PyPDF2.PdfReader(pdfFile)

# %%
reader = PyPDF2.PdfReader('celesc-2023-09-02.pdf')
page = reader.pages[0]
txt = page.extract_text()
lista = txt.split('\n')
df = pd.DataFrame(lista)

# %%
reader = PyPDF2.PdfReader('celesc.pdf')
page = reader.pages[0]
txt = page.extract_text()
lista = txt.split('\n')
df2 = pd.DataFrame(lista)

# %%
df
# Out:
#                                                                                                                                                                                                                                                  0
# 0                                                                                                                                                                                                                          Celesc Distribuicao S.A
# 1                                                                                                                                                                                                             Av Itamarati, 160 -  - Florianopolis
# 2                                                                                                                                                                                            CNPJ: 08.336.783/0001-90 Insc.Est.: 255266626Conta de
# ...

# %%
df2
# Out:
#                                                                                                                                                                                                                                                  0
# 0                                                                                                                                                                                                                                      Segunda Via
# 1                                                                                                                                                                                                                                      Segunda Via
# 2                                                                                                                                                                                                               Segunda ViaCelesc Distribuicao S.A
# ...

# %%
string = "Data da leitura anterior:"
dfX = df.loc[df[0].str.contains(string)]
dfY = df2.loc[df2[0].str.contains(string)]

# %%
dfX
# Out:
#                                        0
# 17  Data da leitura anterior: 19/07/2023

# %%
data_index = dfX.index.values[0]

newDf = df[df.index == data_index]
date_string = newDf.values[0][0]
date_string.split(":")[1].strip()
# Out:
# '19/07/2023'

# %%
dfX2 = df[df.index == dfX.index.values[0]+1]

# %%
dfX2.values[0][0]
# Out:
# 'Data da leitura atual: 16/08/2023'

# %%
df2
# Out:
#                                                                                                                                                      0
# 6  EMISSÃO: 16/02/2024 APRES.: 19/02/2024 NOTA FISCAL/CONTA DE ENERGIA ELÉTRICA - SÉRIE ÚNICA: 000.249.514.290 - FAT-01-202411136312055-5 REF.:02/2024

# %%
df[(df.index >60) & (df.index <100)]
# Out:
#                                                                                                                            0
# 61                                                                                                                     LIGUE
# 62                                                                                       0800 048 0120CONSUMO TOTAL FATURADO
# 63                                                                                                                 1.109 kWh
# 64                                                                                                    VALOR ATÉ O VENCIMENTO
# 65                                                                                                                 R$ 488,64
# 66                                                                                                                Mensagens:
# ...

# %%
df.loc[df[0].str.contains("VALOR ATÉ O VENCIMENTO")].index.values[0]
# Out:
# 64

# %%
valor_float = float( df[df.index == 64+1][0].values[0].split(" ")[1].replace(',','.')  )
valor_float
# Out:
# 429.17

# %%
class CelescBillPdfDataExtractor():
    __init__(this, pdfFilePath: str)
